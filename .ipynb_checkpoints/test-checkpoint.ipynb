# %%
import sentiment_mod as s
import pandas as pd
from datetime import datetime
import Stock_Market_web_scraper as getData
from tqdm.auto import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
months_dict = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}
def plotter(stock_name):
    df,df_price = getData.get_stock_data(stock_name)
    curr_month = datetime.now().month
    
    months_labels = []
    for i in range(1,13):
        months_labels.append(curr_month-i)
    months_dict_temp = {}
    for i,month in zip(months_labels,months_dict.values()):
        months_dict_temp[i] = month
    
    def remove_this_week(text):
        if ('day' in text) or ('week' in text) or ('hour' in text) or ('minute' in text):
            return months_dict[datetime.now().month]
        elif('year' in text):
            return pd.NA
        else:
            month = int(text.split()[0])
            
            if month<datetime.now().month:
                return months_dict_temp[month]
            else:
                month = month-12
                return months_dict_temp[month]
            
    df['dates'] = df['dates'].apply(remove_this_week)
    df.dropna(inplace=True)
    sentiment = []
    for news in tqdm(df['news'],desc = 'Applying Sentiment Analysis'):
        sentiment.append(s.sent(news))
    df['sentiment'] = sentiment

    plot_data = df.groupby('dates',as_index=False).mean()

    fig, (ax1, ax2, ax3) = plt.subplots(figsize=(14, 20), nrows=3, ncols=1)
    order = list(df['dates'].unique())
    order.reverse()
    ax30 = sns.pointplot(plot_data, x='dates', y='sentiment', order=order, ax=ax1)
    ax4 = sns.barplot(plot_data, x='dates', y='sentiment', ax=ax1, order=order)
    ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
    ax1.set_title('Sentiment Plot')

    df_price['dates'] = df_price['dates'].map(months_dict)
    ax5 = sns.pointplot(df_price, x='dates', y='Close', order=list(df_price['dates']), ax=ax2)
    ax6 = sns.barplot(df_price, x='dates', y='Close', order=list(df_price['dates']), ax=ax2)
    ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
    ax2.set_title('Mean stock price plot')

    df_data = pd.DataFrame()
    df_data = pd.merge(plot_data,df_price,on='dates',how='left')
    
    ax300 = sns.lineplot(df_data,x='sentiment',y='Close',ax=ax3)
    ax3.set_title('Stock Price vs Sentiment')
    print('Pearsons correlation:- ',end='')
    print(stats.pearsonr(df_data['Close'],df_data['sentiment'])[0])
    print('Spearmans correlation:- ',end='')
    print(stats.spearmanr(df_data['Close'],df_data['sentiment'])[0])
    np.set_printoptions(suppress=True)
    print('Correlation matrix:- ')
    print(df_data.corr())
    
    
    plt.subplots_adjust(hspace=0.5)
#     plt.suptitle(stock_name)
    return fig,df_data,df,df_price

# %%
fig,df_data,df_news,df_price = plotter('reliance')
# Out:
# Extracting Headlines:   0%|          | 0/200 [00:00<?, ?it/s]
# Adding Headlines:   0%|          | 0/1200 [00:00<?, ?it/s]
# Applying Sentiment Analysis:   0%|          | 0/1200 [00:00<?, ?it/s]
# Pearsons correlation:- 0.5302296520063268
# Spearmans correlation:- 0.5454545454545455
# Correlation matrix:-
#            sentiment    Close
# sentiment    1.00000  0.53023
# Close        0.53023  1.00000

# %%
# import tkinter as tk
# from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
# from matplotlib.figure import Figure


# # Create the Tkinter window
# window = tk.Tk()
# window.title("Graph Window")

# # Create a function to display the graph
# def display_graph(fig):
#     fig = fig
#     canvas = FigureCanvasTkAgg(fig, master=window)
#     canvas.draw()
#     canvas.get_tk_widget().pack()

# # Call the display_graph function to show the graph in the Tkinter window
# display_graph(fig)

# # Start the Tkinter event loop
# window.mainloop()

# %%
df_data
# Out:
#         dates  sentiment        Close
# 0       April  -0.061947  2349.000000
# 1      August   0.184466  2610.225098
# 2    December  -0.068493  2604.200073
# 3    February  -0.018519  2361.775024
# 4     January   0.265306  2472.050049
# 5        July   0.009174  2420.449951
# 6        June   0.012987  2516.650024
# 7       March  -0.092784  2275.949951
# 8         May   0.036364  2450.900024
# 9    November   0.186047  2597.649902
# 10    October   0.035294  2432.350098
# 11  September   0.290780  2520.125000

# %%
neg = df_news[df_news['sentiment']==-1]

# %%
neg = list(neg['news'])

# %%
df_news['sentiment'].value_counts()
# Out:
#  1    644
# -1    556
# Name: sentiment, dtype: int64

# %%
df_news.iloc[0].news
# Out:
# 'Mcap: 6 of top 10 valued firms erodes by ₹70,486.95 cr; Reliance, TCS biggest laggards'

# %%
neg
# Out:
# ['Infosys, Reliance Industries, NTPC, Bajaj Finance shares: MFs upped stakes in these stocks in April',
#  'US Ambassador Eric Garcetti’s India visit: Engagements with Mukesh Ambani and Shah Rukh Khan, captured in Photos: See pics',
#  'Day Trading Guide for May 17, 2023',
#  'Tata Motors, RIL, Bajaj Finance: What should be your trading strategy for these 3 stocks?',
#  'Markets fall after two-day rally; HDFC twins, Reliance drag Sensex over 413 points lower',
#  'Reliance-BP selling diesel at Rs 1 discount over PSU rates: Report',
#  'Day Trading Guide for May 16, 2023',
#  'DMart slumps nearly 5 per cent on profit miss, margin drop | The Financial Express',
#  'Day trading guide for May 12, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Day Trading Guide for May 11, 2023',
#  'METRO completes Rs 2,850 cr deal with Reliance Retail to sell its India Cash & Carry business',
#  'Reliance in fray as MG Motor looks to sell India ops: Reports',
#  'Sensex climbs 179 pts in fag-end, Nifty tops 18,300; auto, bank stocks lead',
#  'Day trading guide for May 10, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Infosys, Kotak Mahindra Bank, Reliance Industries, Titan, ITC: Here are top 10 HNI stock bets',
#  'Reliance Industries: Jefferies bull case scenario suggests share price target of Rs 3,450',
#  'Delhi HC dismisses govt appeal accusing Reliance of ‘fraud, unjust enrichment of over $1.729 billion’ for siphoning gas',
#  'Reliance Industries’ capex benefits to flow in FY25, risk-reward attractive: JPMorgan',
#  'LIC portfolio shares: Reliance Industries, ITC, TCS, Infosys & SBI among insurer’s top stock holdings',
#  'Brookfield weighing stake sale in Indian tower business, says report',
#  'Reliance Industries shareholders, creditors approve demerger of financial services biz',
#  'Reliance shareholders, creditors approve demerger of financial services arm',
#  'Sensex, Nifty climb in early trade amid buying in major stocks',
#  'Day Trading Guide for May 4, 2023',
#  'Reliance Industries, Infosys, Tata Steel, SBI, Wipro, ITC shares: Full list of Nifty stock valuations vis-a-vis historical averages',
#  'ITC, Dr Reddy’s, DLF among 67 NSE stocks to hit 52-week highs; 7 touch 52-week lows | The Financial Express',
#  'Day Trading Guide for May 3, 2023',
#  'Amid JioCinema’s aggressive content push, is it a bad time for Amazon Prime Video to hike prices?',
#  'Sensex revisits 61k, Nifty above 18k; RIL, ITC stocks spurt',
#  'Sensex soars 463pts, ends atop 61K; Nifty tops 18050; mid-, smallcaps shine',
#  'Day Trading Guide for April 26, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Jio eyes new horizons with cheap fiber plan | Mint Primer | Mint',
#  'Day Trading Guide for April 25, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Reliance Industries shares: RIL stock may rally up to 83%! What JPMorgan, Goldman Sachs, Morgan Stanley say post Q4 results',
#  'RIL, ICICI Bank shares up on good Q4 numbers, Yes Bank’s open in the negative',
#  'Reliance Industries Q4 Results Review: Outlook Remains Robust Across Verticals, Say Brokerages',
#  'Reliance Industries Q4 earnings beat estimates: Here’s what brokerages say',
#  'Stocks to watch: RIL, ICICI Bank, YES Bank, Hindustan Zinc, Sun Pharma',
#  'Reliance Industries Q4 Profit Beats Estimates — Earnings Wrap',
#  'Reliance Industries, TCS, HDFC Bank, ICICI Bank: 8 of top 10 most valued Indian firms lose Rs 1.17 lakh cr in market valuation',
#  'Eight Of Top 10 Firms Lose Rs 1.17 Lakh Cr In Market Valuation; Infosys Biggest Laggard',
#  'Reliance Industries monitoring OPEC+ supply cut impact on price, demand: CFO',
#  'Reliance Industries Q4 Results Review - Beat On Lower Tax Rate: Dolat Capital',
#  'Reliance Industries’ Net Debt Jumps Over Threefold On Accelerated 5G Capex',
#  'RIL Q4 Results: 8 major takeaways for Dalal Street, what do experts say?',
#  'Reliance Retail’s Q4 net profit rises 13% YoY',
#  'RIL Q4 Results Highlights: Net profit up 19%; new energy investments to drive next growth wave, says CFO',
#  'RIL Q4 Results: Profit jumps 19% YoY to Rs 19,299 cr; revenue up 2% at Rs 2.16 lakh cr',
#  'Sensex, Nifty settle flat in subdued trading; Reliance Industries earnings eyed',
#  'Reliance Industries Q4 results: RJio revenue seen at Rs 23,400 crore; here’re estimates for retail, energy businesses',
#  'RIL Q4 results: Net profit rises 19% to Rs 19,299 crore. Here’s what Mukesh Ambani says',
#  'Taking Stock | Bulls charge the market to end FY23 with Sensex up 1,031, Nifty above 17,300',
#  'Bernstein Research removes IEX short, adds RIL, Biocon, M&M to portfolio',
#  'Another lacklustre day on the cards for domestic markets',
#  'Day Trading Guide For April 21, 2023',
#  'O2C segment may drive RIL’s Q4FY23 revenue; retail, telco stable: Analysts',
#  'Reliance Retail Q4FY23 Earnings Preview: Revenue May Cross The ₹ 70,000 Crore Mark | CNBC-TV18',
#  'Reliance Industries Q4 Preview: Net Profit Expected To Drop, Ebitda Set To Rise',
#  'Day Trading Guide For April 20, 2023',
#  'Day Trading Guide for April 19, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Reliance Industries shares fall ahead of Q4 earnings: RIL results date, stock price targets, analyst previews & more',
#  'Kotak Bank, Infosys, Bajaj Finance, Tata Motors, TCS: How mutual funds’ top March stock bets fared in results season',
#  'Reliance Industries to Release Q4 Earnings This Week',
#  'After free cricket IPL, JioCinema is foraying into original content',
#  'James Murdoch’s Bodhi Tree slashes planned investment in Reliance JV Viacom18 by 70% to Rs 4,306 crore',
#  'RIL to set up $2.4-3 bn InvIT to monetise retail warehousing assets',
#  'Mukesh Ambani’s Reliance Industries plans to float Rs 20,000-cr InvIT to monetise retail warehousing assets',
#  'Infosys, IndusInd Bank, Maruti Suzuki, Bajaj Finserv: Stocks that 5 top insurance cos bought & sold in March',
#  'Reliance Industries Ltd readies $2.4-3 billion InvIT for retail warehousing assets',
#  'RIL readies $2.4-3 bn Infra Investment Trust for retail warehousing assets',
#  'Day Trading Guide for April 12, 2023',
#  'Day Trading Guide for April 11, 2023',
#  'Torrent Power pips Reliance to emerge as lowest bidder for Indian power supply contract: Sources',
#  'Reliance Industries shares: As stock lags Sensex, can Q4 results set stage for recovery?',
#  'Amul India’s former MD Sodhi joins Reliance Retail’s grocery division',
#  'RIL, ITC, TCS, SBI, Infosys: How LIC’s top 10 stock holdings fared in 2023 so far',
#  'Amul|Reliance Retail: Former Amul managing director RS Sodhi joins Reliance Retail in advisory role',
#  'Day Trading Guide for April 05, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'After $3 bn, Reliance Industries, Jio raise $2 bn foreign exchange loan',
#  'Mukesh Ambani, with $83.4-bn net worth, among world’s richest; Zerodha’s Kamath brothers new billionaires: Forbes',
#  'Global, Indian FMCG companies in race for Capital Foods',
#  'Reliance’s JioCinema clocks record 1.47 bn digital views in 1st IPL weekend',
#  'Market Wrap: Dalal Street snapped a three-week losing streak amid easing concerns around stress in banking sector',
#  'Reliance Industries planning major investment in Australia’s energy sector',
#  'Sensex climbs 600 pts, Nifty tops 17,250; RIL shares gain ahead of board meet on biz demerger',
#  'Reliance Industries shares top Rs 2,300 level, surge 4% as creditors to consider biz demerger on May 2',
#  'Stocks to watch: RIL, Tata Power, Hero MotoCorp, Shakti Pumps, BDL, RVNL',
#  'Day Trading Guide For March 31, 2023',
#  'Reliance Industries’ creditors, shareholders to meet on May 02 on demerger of financial services business',
#  'Bharti Airtel falls 3% in two days; stock nears 6-month low',
#  'RIL infuses ₹1,500 crore into Sintex Industries under resolution plan',
#  'Reliance Industries shares: Reasons behind the recent weakness in RIL stock, price targets & more',
#  'Sensex, Nifty Decline Dragged By Losses In Reliance Industries: Mid-Day Market Update',
#  'Reliance Industries completes Sintex Textiles acquisition',
#  'Day Trading Guide For March 29, 2023',
#  'Day Trading Guide For March 28, 2023',
#  'RIL ties up with three IPL teams to plug Campa Cola',
#  'Reliance Industries shares: Recent weakness puzzling, RIL stock a compelling Buy, says Kotak Securities',
#  'Stocks that will see action on March 27, 2023',
#  'Five Of Top 10-Firms Lose Rs 86,447 Crore In M-Cap; Infosys, TCS, SBI Hit Hard',
#  'Five of top 10 firms lose Rs 86,447 crore in market cap; Infosys, TCS, SBI hit hard',
#  'Reliance Industries appoints Venkatachari Srikanth as new CFO, Alok Agarwal named Senior Advisor to Mukesh Ambani',
#  'RIL CFO Alok Agarwal to assume role of senior advisor to Mukesh Ambani',
#  'Reliance Industries names new chief financial officer',
#  'Reliance Industries names Srikanth Venkatachari as new CFO',
#  'Titan Share Price | Reliance Share Price: Time to buy Titan and short Reliance, says Rahul Sharma',
#  'Sensex, Nifty fall amid weak trend in Asian equities',
#  'Reliance Jio’s new 5G plans may impact Bharti Airtel’s key metrics- JP Morgan',
#  'Markets fall in early trade tracking weak global equities',
#  'Stocks To Watch: Hindustan Aeronautics, Hero MotoCorp, Reliance Industries, GR Infra, Max Financial',
#  'Reliance Industries, ZEEL, HDFC Life Insurance: How should you trade these stocks',
#  'Hindenburg impact: Gautam Adani lost Rs 3,000 cr every week over last 12 months, says Hurun report',
#  'Ambani among top 10 billionaires, Adani at 23rd: M3M Hurun Global Rich List',
#  'Reliance Industries shares: Three factors that can lead recovery from 52-week low',
#  'Reliance Industries Snaps 8-Day Losing Streak | ET Now',
#  'Reliance Industries plans hotels, resorts near Statue of Unity in Gujarat',
#  'Day Trading Guide for March 21, 2023',
#  'Sensex Jewel: Reliance Industries Jumps 3.3%, Snaps 8-Day Losing Run',
#  'Reliance Industries shares hit fresh 52-week low today, slip below Rs 2,200 mark',
#  'Everybody’s a bull on Reliance but the stock is at a 52-week low. Here’s why',
#  'Reliance Industries shares: FII ownership at 6-year low. Should you buy, hold or sell RIL stock?',
#  'Taking Stock | Market back to losing ways; Sensex down 542 points, Nifty slips below 17,600',
#  'Day Trading Guide for March 17, 2023',
#  'JP Morgan revises Reliance Industries stock target price, sees 33% uptick',
#  'SVB impact: Sensex slumps 897 pts, Nifty ends near 17,150; PSBs worst hit',
#  'what is the f&o strategy for nifty 50 and reliance industries',
#  'Reliance Industries shares slip 9% in six sessions: Four factors behind the fall',
#  'Reliance Industries shares hit new 52-week low, down 14% so far this year; analysts see more downside',
#  'Reliance market-cap falls below Rs 15 trillion; stock down 9% in six days',
#  'Day Trading Guide For March 16, 2023',
#  'Why RIL Has Been Declining In Trade | ET NOW',
#  'RIL, Mphasis: 45 stocks hit fresh 52-week lows; charts show more pain ahead',
#  'Reliance Industries Ltd slips for fifth straight session',
#  'This Chris Wood owned stock hit a 52-week low. What’s worrying the Street?',
#  'Day Trading Guide for March 15, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Reliance Industries shares hit 52-week low; here’s the new price target',
#  'SVB impact: Sensex slumps 897 pts, Nifty ends near 17,150; PSBs worst hit',
#  'Ten more banks set to join syndication for Reliance Industries Ltd’s $3 billion loan',
#  'Eight of top-10 firms lose Rs 1.03 trn in market-cap; RIL, ICICI hit hard',
#  'Eight of top 10 firms lose Rs 1.03 lakh crore m-cap; RIL, ICICI hit hard',
#  'Eight of top 10 firms lose Rs 1.03 lakh crore in market valuation; RIL, ICICI hit hard',
#  'what is futures and options guidance on reliance industries stock',
#  'Stocks To Watch: Bank Of Baroda, Reliance Industries, Ujjivan Small Finance, REC, Zydus Lifesciences',
#  'Day Trading Guide for March 9, 2023',
#  'Reliance Industries vs Infosys: Which heavyweight stock can deliver better returns in near term?',
#  'Reliance Industries: Can the share price fall more?',
#  'Reliance Industries plans to set up 10 GW solar project in Andhra Pradesh',
#  'Day trading guide for March 03, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Stocks in news: Paytm, Delhivery, NTPC, Reliance Industries and more',
#  'EV Stock jumps 35% in 2 trading days after partnership with Reliance industries',
#  'Nine Of Top 10 Firms Lose Rs 1.87 lakh Crore In Market Valuation; HDFC Bank, RIL Hit Hard',
#  'Nine of top 10 firms lose Rs 1.87 trn in mcap; HDFC Bank, RIL hit hard',
#  'Olectra Greentech stock surges 17% on tie-up with Reliance Industries for hydrogen bus',
#  'Day Trading Guide for February 24, 2023',
#  'Opening bell: Sensex in red at 59,652, Nifty falls to 17,520',
#  'Day Trading Guide for February 23, 2023',
#  'Sensex tumbles over 900 points to settle at 59,745, Nifty in red at 17,554',
#  'Mukesh Ambani to stream IPL for free after paying $2.7 billion',
#  'Mukesh Ambani’s conglomerate to stream IPL for free after paying $2.7 bn',
#  'Tata Power Stocks | Reliance Industries Stocks: What should you do with Reliance Industries & Tata Power? Gurmeet Chadha explains',
#  'Stocks that will see action on February 22, 2023',
#  'Day Trading Guide for February 21, 2023',
#  'Adani stocks: Group’s market value now even lesser than top 3 biggies',
#  'Sensex, Nifty pare early gains to settle lower for second straight session',
#  'Closing bell: Sensex ends in red at 60,692, Nifty slumps to 17,845',
#  'Charts indicate robust bias for RIL, ONGC amid GST inclusion hopes',
#  'GAIL imitates Reliance: Plans to import ethane from United States',
#  'Day Trading Guide for February 17, 2023: Intraday supports, resistances for Nifty50 stocks',
#  'Day Trading Guide for February 16, 2023',
#  "#MARKETTODAY Sensex Off Day's Low; Nifty Above 17,900; VIX Eases 5%",
#  'Reliance Inds gains after NCLT approves RIL-ACRE resolution plan for Sintex Industries',
#  '#MARKETTODAY Sensex, Nifty flat; RIL, Tech M, Maruti Rise Up to 1%',
#  'In opening session, Sensex dips to 60,806, Nifty in red at 17,837',
#  'Day trading guide for February 15, 2023: Intraday supports, resistances for Nifty 50 stocks',
#  'Day Trading Guide For February 14, 2023',
#  'RIL’s green transition to be value-accretive, see stock at Rs3,100: Jefferies',
#  'Reliance Industries: Is it a Stock In Peril',
#  'Stocks that will see action on February 13, 2023',
#  'Six of top-10 firms lose Rs 49,231 crore in m-cap; HUL biggest laggard',
#  'Sensex ends week in red at 60,683, Nifty slumps to close at over 17,850',
#  'Sensex dips 124 pts, smallcaps shine; Paytm cracks 9%, Tata Motors up 2%',
#  'Day Trading Guide for February 10, 2023',
#  'Sensex drops nearly 115 points in early trade; Nifty tests 17,800',
#  'Markets trade in red with Sensex at 60,550, Nifty at 17,808',
#  'Mukesh Ambani’s Reliance Industries launches India’s first hydrogen ICE truck with Ashok Leyland',
#  'Adani’s crisis points to the big risk in India’s net zero plan',
#  'Viacom18 aiming for ad revenues worth Rs 3700 crore from IPL 2023',
#  'Day Trading Guide for February 3, 2023',
#  'Stocks that will see action on February 1, 2023',
#  'Taking Stock | Investors cautious ahead of inflation data; Sensex, Nifty end lower',
#  'Reliance to bring Sri Lanka’s Maliban biscuit into India',
#  'Hindenburg report: Adani loses $34bn in 3 days, now only 11th richest',
#  'Seven of top-10 firms shed Rs 2.16 lakh crore in mcap; RIL, SBI hit hard',
#  'Seven of top-10 firms shed Rs 2.16 trillion in m-cap; RIL, SBI hit hard',
#  'Sensex, Nifty tumble over 1% on selling in banking shares, Reliance Industries',
#  'Markets end week in red with Sensex at 59,331, Nifty at 17,604',
#  'Reliance Industries hits 10-month low, stock slips 15% since December',
#  'Opening bell: Sensex 578 points in red at 59,627, Nifty slumps to 17,747',
#  'Markets in red as Sensex slumps to 60,710, Nifty at 18,028',
#  'India bluechips to shift to world’s fastest settlement cycle T+1 this week',
#  '#MARKETTODAY | Yes Bank Dips 10% Post Q3, Bombay HC Order. What Should Investors Do?',
#  'Reliance Industries gains 1% post December quarter earnings',
#  'Reliance Industries reports Q3 results: What should investors do now?',
#  "RIL's Q3 Revenue Increases By 15.3% YoY, EBITDA Growth Beats Estimates | Power Breakfast | CNBC-TV18",
#  'Reliance Industries Q3 Results Review - Standalone Business Delivers With Improved Realisations: Motilal Oswal',
#  'Absence of immediate drivers puts Reliance Industries stock in back seat',
#  'Reliance EBIDTA Jumps 13% QoQ | Relief For Yes Bank Bond Holders | Top Headlines',
#  'Reliance Industries consolidated net profit declines 14.86% in the December 2022 quarter',
#  'Reliance Industries Q3 Results LIVE | इस बार भी मुनाफे में नजर आई बढ़त? क्या कहते है EBITDA के आकड़े?',
#  'Jio corners 50% home broadband market',
#  'RIL Oil-To-Chemicals Business Reports Strong Growth | Reliance Q3 Earnings | India Business Hour',
#  'Reliance Industries’ Q3 revenue rises 15% on all-round performance',
#  'Reliance Industries’ PAT dips 15% YoY, revenue up 15% on all-round performance',
#  'Reliance Q3 profit slumps 15% YoY to Rs 15,792 crore, misses estimates',
#  'Reliance Jio Q3 profit rises by 28% to Rs 4,638 cr, revenue up 19% YoY to Rs 22,998 crore',
#  '5x in 5 years! How Reliance Industries stock has given terrific returns since 2017',
#  'Buzzing stocks: Reliance Industries, JSW Steel, HDFC Life, HUL and more',
#  'Sensex, Nifty fall for second day on losses in RIL, HUL',
#  'Stocks that will see action on January 20, 2023',
#  'Stocks to Watch: HUL, Adani Ent, Hindustan Zinc, LTTS, PVR, AUSFB',
#  'Consumer business boosts Reliance Industries’ consolidated revenues to Rs 2.40 lakh crore in Q3 FY23',
#  'Reliance Industries and BP suspends gas auction after cap on traders’ margin',
#  'Sensex, Nifty decline as metal, financials shares retreat amid FII outflows',
#  'Ahead of 2024 general elections, Modi govt has a plan for India’s small retailers',
#  'Sensex, Nifty pare early gains to close close lower as financials, oil stocks fall',
#  'Govt caps trading margin on resale of gas from deep sea fields',
#  'Markets end on flat note amid unabated foreign fund outflows and weak trend',
#  'Markets flat as Sensex closes in red at 60,106, Nifty slumps to 17,896',
#  'Opening bell: Markets trade in red as Sensex slumps to 59,806, Nifty at 17,824',
#  'Q3 preview: RIL may report broad-based growth but 10% YoY profit decline',
#  'Sensex crashes 632 points to close at 60,115, Nifty in red at 17,914',
#  'Market closing alert: Sensex climbs 847 points to settle at 60,747, Nifty in green at 18,101',
#  'Reliance Industries to enter FMCG segment with equal focus on backend sourcing, says report',
#  'Mcap: Eight of top 10 firms lose ₹1 lakh cr; Infosys, HDFC Bank, TCS biggest laggards',
#  'Sensex falls for 3rd day, ends below 60k',
#  'Govt likely to award MMLPs at Bengaluru, Nagpur and Indore by March 2023',
#  'Stocks in news: Reliance Industries, NTPC, Railtel, Avenue Supermarts and more',
#  'Can Reliance Industries shares hit Rs 3,250? What UBS, others say ahead of December quarter results',
#  'Opening bell: Markets decline in initial trade',
#  'Sensex, Nifty drop in early trade; BF Utilities surges 20%, banks shine',
#  "Reliance Industries' CMD Mukesh Ambani Shares His Success Mantra | Listen In | Shorts | CNBC-TV18",
#  'Ambani’s ‘target setup’ for his 3 children in succession plan',
#  'World sees 21st Century as India’s, we can be USD 40 trillion economy by 2047: Mukesh Ambani',
#  'Reliance Industries topped the growth charts in the last 20 years',
#  'Reliance Industries’ 20 years under Mukesh Ambani: Major achievements',
#  'Mukesh Ambani completes 20 years at helm of Reliance Industries',
#  'Sensex starts day in red by slumping over 100 points at 60,825, Nifty at 18,091',
#  'Day Trading Guide for December 27, 2022',
#  'Will Reliance Industries’ stock finally hit Rs 3,000 in 2023?',
#  'Market Cap Of 10 Most Valued Firms Erodes By Rs 1.68 Lakh Crore; Reliance Biggest Drag',
#  'Lanco Amarkantak resolution faces delays',
#  'RIL, JSW Steel, PB Fintech, Jubilant Food and Sundaram Finance: What analysts said on these 5 stocks',
#  'RIL, Abans Holdings, Landmark Cars, Godrej Properties in focus',
#  'Day Trading Guide for December 23, 2022',
#  'Reliance industries subsidiary acquires 23.3% stake in Exyn Technologies',
#  'Day Trading Guide for December 22, 2022',
#  'D-St selloff in numbers: Rs 4.5 lakh cr investor wealth erased; 60 stocks hit 52-week lows; 3 of 4 stocks in red',
#  'Sensex bounces 599 pts from lows, ends 104 pts down; Nifty tops 18,350',
#  'Metro AG global CEO Steffen Greubel hints at exiting India',
#  'Benchmark indices rise nearly 1% on heavy buying in oil, FMCG stocks',
#  'Reliance Foundation collaborates with Yakult to support Young Champs',
#  'Availing input tax credit has become a task: Reliance Industries tax official',
#  'Five things to know about Reliance Industries stock in 2022',
#  'Day Trading Guide For December 16, 2022',
#  'Reliance Industries Ltd is India’s most-visible company, says report',
#  'Reliance Industries tops charts on Wizikey Newsmaker Ranking',
#  'Reliance hit most as top 5 out of 10 firms lose ₹1.67 lakh crore in m-cap',
#  'Five of top-10 firms lose Rs 1.67 lakh crore in m-cap; RIL biggest drag',
#  'Five of top-10 firms lose Rs 1.67 trn in m-cap; RIL biggest drag',
#  'Rs 13 lakh crore! After remaining sideways for a decade, RIL stock becomes largest wealth creator in last 5 yrs',
#  'Sensex tumbles 389 points to close at 62,182, Nifty in red at 18,497',
#  'Lenders to SKS Power give bidders a fourth deadline extension for due diligence',
#  'Day Trading Guide for December 09, 2022',
#  'Top 100 firms create ₹92.2 lakh cr wealth led by Reliance, 2 Adani companies',
#  'Day Trading Guide for December 06, 2022',
#  'Sensex slips nearly 34 points on profit taking in oil, auto stocks',
#  'Indices close on mixed note as Sensex falls to 62,835, Nifty in green at 18,701',
#  'Day Trading Guide for December 02, 2022',
#  'Mukesh Ambani-led Reliance Industries tops Hurun’s list of most valuable companies in India',
#  'Reliance Industries shares in overbought zone; can they hit Rs 3,100 mark?',
#  'TCS has more female employees than any company in India, says survey. Which are other firms?',
#  'What’s powering the rally in Reliance Industries’ stock?',
#  'Day Trading Guide for December 01, 2022',
#  'Reliance Industries Ltd spurts 0.53%, gains for five straight sessions',
#  'Markets end in green as Sensex closes at 62,504.80; Nifty settles at 18,562.75',
#  'An epic Ambani versus Adani clash over a Lanco asset has been put off for now',
#  'Markets end in green as Sensex closes at 62,293; Nifty settles at 18,512',
#  'Sensex, Nifty end flat after listless trade; auto stocks rally, banks fall',
#  'Day Trading Guide for November 25, 2022',
#  'Day Trading Guide for November 24, 2022',
#  'Paytm slumps to new low as Macquarie sees risk from Ambani’s financial foray',
#  'Day Trading Guide for November 22, 2022',
#  'Bharti Airtel, Axis Bank, Reliance Industries, HDFC among top gainers & losers as market ends lower',
#  'Sensex slumps over 500 points to settle at 61,145, Nifty in red at 18,160',
#  'Market alert: Sensex trading in red at 61,200, Nifty falls to 18,178',
#  'Jio-BP says fuel supply by company not intermittent',
#  'Day Trading Guide for November, 18, 2022',
#  'Day Trading Guide For November 16, 2022',
#  'Day Trading Guide For November 15, 2022',
#  'Indian benchmark Indices end lower on Monday amid high global volatility, Sensex closes at 61,624',
#  'Mukesh Ambani to bid for football club Liverpool FC’s takeover: Report',
#  'Reliance retail, Adani group companies among bidders for Future Retail',
#  'Reliance to develop multi-modal logistics park in Tamil Nadu',
#  'Sensex Surges 1,181 Points, Nifty Above 18,300; IT, Metal, Financial Stocks Lead',
#  'RIL, Adani JV, 13 others put in EoIs for Future Retail',
#  'Reliance Jio launches 5G services in Bengaluru and Hyderabad',
#  'Reliance Industries Ltd soars 0.36%, up for fifth straight session',
#  'KV Kamath to join RIL board as independent director for 5 years',
#  'Day Trading Guide For November 3, 2022',
#  'NTPC, PowerGrid, Axis Bank, Maruti among top gainers & losers as market ends higher',
#  'Stocks to Watch: IOC, Vedanta, RIL, NTPC, Nykaa, Hero Moto, Dr Reddy, Sugar',
#  'Sensex, Nifty rally for second day amid foreign fund inflows',
#  'Day Trading Guide for October 28, 2022',
#  'How India’s Bingeing On Russian Oil Is Hitting Middle East',
#  'Day Trading Guide for October 27, 2022',
#  'What does demerger of the financial services biz mean for RIL shareholders?',
#  'Markets end in red: Sensex down 288 points at 59,544, Nifty at 17,656',
#  'Reliance Industries Q2 Results Review - Subdued Oil-to-Chemical Segment Performance: HDFC Securities',
#  'Reliance Industries Q2 Review - Weak Quarter, Oil-to-Chemical Prospects Key To Revival: ICICI Securities',
#  'Reliance Industries Q2 Results Review - Commendable Performance By Jio, Retail Segments: IDBI Capital',
#  'Reliance Industries Q2 Results Review - Windfall Taxes Impact Oil-to-Chemical Margins: ICICI Direct',
#  'Stocks to watch: RIL, HUL, ICICI Bank, RBL Bank, IGL, Borosil Renewables',
#  'Reliance to commission its deepwater MJ gas condensate field by year-end',
#  'Nifty Ends Accounting Year With A Loss | Big Giants All Set To Announce Quarterly Earnings|Headlines',
#  'RIL to restructure group EPC resources',
#  'Reliance Industries consolidated net profit declines 0.18% in the September 2022 quarter',
#  'Board of Reliance Industries Ltd to restructure group EPC resources',
#  'RIL Q2 Results: Profit dips marginally to Rs 13,656 crore, misses D-St estimates',
#  'Reliance Industries Q2 Results: Profit Falls 20% On Lower Margins, Still Beats Estimates',
#  'Reliance Industries’ second quarter profit hit by windfall tax',
#  'Reliance Industries Q2 profit at Rs 13,656 crore; revenue up 34%',
#  'MoEF panel nod to RIL’s Hazira manufacturing complex’s Rs 10k Cr expansion, debottlenecking',
#  'Reliance Industries Ltd spurts 2.13%, up for third straight session',
#  'Day Trading Guide for October 19, 2022',
#  'JP Morgan elevates Kaustubh Kulkarni as India head',
#  'Sensex, Nifty rise for second day as oil, banking stocks advance',
#  'Many India Inc majors may be Net-Zero by 2050',
#  'Six of top-10 firms lose Rs 78,163 crore in m-cap; RIL biggest drag',
#  'Reliance Industries Infrastructure records 11.4% drop in Q2 net profit',
#  'Diwali picks: Jayesh Bhanushali on 8 stocks he is betting on',
#  'HCL Tech, Sun Pharma, Wipro and SBI among top gainers & losers as market ends lower',
#  'Day Trading Guide for October 13, 2022',
#  'Day Trading Guide for October 12, 2022',
#  'Reliance Industries shares slip over 7% in a month, what lies ahead?',
#  'Reliance Industries, Jio in talks to raise funds through foreign loans',
#  'Day Trading Guide For October 7, 2022',
#  'Day Trading Guide For October 6, 2022',
#  'Mid-course changes in gas pricing to delay investments, says Reliance',
#  'Sanmina and Reliance Industries Complete Manufacturing JV Transaction in India',
#  'Day Trading Guide For October 4, 2022',
#  'Hot Stocks: Brokerages on Reliance Industries, Delhivery and Infosys',
#  'RIL, ONGC, OIL: Will gas price hike fire up a bull phase in related stocks?',
#  'Seven of top-10 firms lose Rs 1.16 lakh cr in mcap; Reliance worst hit',
#  'Seven of top-10 firms lose Rs 1.16 trn in mcap; Reliance worst hit',
#  'Mcap of 7 of top-10 firms lose ₹1.16 lakh crore; Reliance Industries worst hit',
#  'PM Modi launches 5G services in India, Airtel and Jio 5G plan rollout to start soon',
#  'Vi will soon begin the 5G rollout journey: Kumar Mangalam Birla at IMC 2022',
#  'Reliance’s retail unit launches its first in-house fashion store Azorte',
#  'Reliance Industries’ stock hits over 6-month low; slips 7% in one week',
#  'Reliance Industries’ stock price drops by more than 5% in the past week',
#  'Day Trading Guide for September 29, 2022',
#  'Sensex, Nifty sink for sixth straight session; metal, banking shares top losers',
#  'Markets settle in red as Sensex tumbles over 500 points to 56,598, Nifty at 16,859',
#  'Markets open in red as Sensex drops by 473 points; Nifty opens below 17,000',
#  'Reliance Industries shelves plan for separate ecommerce marketplace for third-party sellers',
#  'Day Trading Guide for September 27, 2022',
#  'Seven of Top-10 Firms Lose Rs 1.34 Lakh Crore in Market Capitalisation',
#  'Mcap: Seven of top-10 firms lose ₹1.34 lakh cr; RIL biggest laggard',
#  'Seven of top-10 firms lose Rs 1.34 trn in mcap; RIL biggest laggard',
#  'Day Trading Guide for September 23, 2022',
#  'Day Trading Guide for September 22, 2022',
#  'Gautam Adani briefly becomes world’s second richest man again: Report',
#  'Mcap of Six of Top-10 Most Valued Firms Tumble Rs 2 Lakh Crore; TCS, Infosys Biggest Laggards',
#  'Closing bell: Sensex crashes by nearly 1,100 points; Nifty too closes in red',
#  'Day Trading Guide For September 15, 2022',
#  'SBI becomes third Indian lender to surpass Rs 5 trillion market cap',
#  'Equities fall in early trade; Sensex slides 530 points',
#  'SKS Power’s lenders extend timeline for due diligence',
#  'Stocks that will see action on September 12, 2022',
#  'Reliance Industries Arm to Acquire Polyester Business of Shubhalakshmi Polyesters at Rs 1592 Crore',
#  'RIL to acquire polyester business of Shubhalakshmi Polyesters & Shubhlaxmi Polytex',
#  'Sensex slumps 474 points to 58,723, Nifty falls to 17,484',
#  'Stocks to Watch: DreamFolks, RIL, HAL, L&T, Adani, Tata Motors, REC, NTPC',
#  'Three of the top ten companies lose Rs1.22 trillion in market capitalization, last week',
#  'MSTC eyes e-commerce biz; ties with Reliance, Vedanta, Tata Power, others',
#  'Three of Top-10 Firms Lose Rs 1.22 Lakh Crore in Market Capitalisation',
#  'Three of top-10 firms lose Rs 1.22 trn in mcap; RIL biggest laggard',
#  'Will Reliance Retail disrupt the FMCG market?',
#  'Windfall tax: Reliance Industries shares fall 3%; ONGC, Vedanta too decline',
#  'Sensex drops over 1,000 pts intra-day: Top factors behind Thursday’s crash',
#  'Sensex sinks 770 pts, Nifty gives up 17,550 amid global sell-off; PSBs soar',
#  'Markets opening bell: Sensex declines nearly 900 points to 58,638, Nifty 274 points in red at 17,486',
#  'ONGC-Indian Oil, GAIL and MCPI submit bids for bankrupt JBF Petro',
#  'Reliance Industries | Growth का अमृत काल: New Generation को मिली बड़ी जिम्मेदारी, क्या है Mega Plan ?',
#  'RIL paves way for the future but risks linger',
#  'Stocks in news: Reliance Industries, Quick Heal, Axis Bank, Lupin and more',
#  'Reliance Industries’ Ambitious Growth Plans May Dent Return Ratios, Say Analysts',
#  'Mukesh Ambani commits ₹2-lakh cr to roll out 5G in metros by Diwali',
#  'Top Headlines: Adani becomes world’s 3rd-richest; Ambani’s plans for RIL',
#  'Pandya hits ball out of the park in endorsement world',
#  '10 takeaways from Reliance’s AGM: 5G launch by Diwali, succession plan, Rs 75k crore investment in petchem & more',
#  'Share Market Live: Sensex falls 750 pts, Nifty below 17,350; RIL stock flat as AGM begins',
#  'Share Market update: Sensex falls 861 pts, Nifty below 17,350; RIL stock ends flat',
#  'Stocks in news: Reliance Industries, NTPC, Cipla, RITES and more',
#  'Reliance Industries AGM 2022: RIL shares close flat in a weak market',
#  'Jio to launch 5G by Diwali, aims to cover entire country by 2023, Mukesh Ambani tells shareholders',
#  'RIL AGM 2022: Reliance Plans to Accelerate Rs 75,000-Crore Investment in New Energy, Says Mukesh Ambani',
#  'LIVE: RIL 45th AGM of Reliance Industries | Mukesh Ambani Speech | Reliance News | CNBC-TV18',
#  'RIL AGM 2022: From 5G rollout by Diwali to launching Jio Cloud PC - Here are 10 major takeaways from Mukesh Ambani’s speech',
#  'Reliance Industries Trims Losses In Weak Market Ahead Of 45th AGM',
#  'Stocks to watch: RIL, Britannia, NHPC, Cipla, InterGlobe Aviation, RITES',
#  'M-Cap of Seven of Top-10 Valued Firms Tumbles Over Rs 1.54 Lakh Crore',
#  'Reliance Industries to put related party transactions up for vote in the annual shareholder meeting',
#  'RIL AGM: No fireworks likely, but Ambani may spell out details on succession plan',
#  'What should investors expect from RIL’s 45th AGM?',
#  'Day Trading Guide for August 26, 2022',
#  'Reliance Industries Annual Report Analysis - Stellar Performance Ahead, But Priced Into CMP: ICICI Securities',
#  'M-cap of five of top 10 firms declines Rs 30,737.51 cr, RIL biggest loser',
#  'Mcap of Five of Top-10 Firms Declines Rs 30,737.51 Crore',
#  'Market Cap Of Five Of Top 10 Firms Declines By Rs 30,737.51 Crore Last Week',
#  'Mcap of five of top-10 firms declines ₹30,737.51 cr last week',
#  'Mcap of five of top-10 firms declines Rs 30,737.51 cr last week',
#  'Lenders agree to RNTL-Reliance Industries’ takeover deal: Report',
#  'Sensex@60K: This isn’t a bear market rally! Here’s why',
#  'Day Trading Guide for August 16, 2022',
#  'Russia-backed Indian refiner Nayara Energy posts record profit',
#  'Reliance Industries Invested Rs 73,764 Crore Outside Three Core Businesses In FY22',
#  'What Reliance Industries’ Annual Report Says About Related-Party Transactions',
#  'Mumbai Indians goes global; names of franchises in UAE, SA T20 Leagues unveiled',
#  'Lenders opt for forensic audit of Future Retail',
#  'Mukesh Ambani Draws No Salary In 2021-22, 2nd Such Year In A Row',
#  'Jio completes 5G coverage planning in top 1,000 cities: RIL annual report',
#  'Mukesh Ambani draws nil salary for 2nd year in row in light of pandemic',
#  'Mukesh Ambani draws nil salary for second year in row',
#  'Reliance Industries fixes record date for dividend for the FY 2021-22',
#  'Subex stock locked in upper circuit for third straight session',
#  'Markets end in red: Sensex settles at over 58,000, Nifty closes at 17,382',
#  'Sensex, Nifty Slip In Volatile Session; Reliance Industries Falls: Mid-Day Market Update',
#  'How many EPS downgrades has Nifty seen this earnings season?',
#  'Day Trading Guide For August 2, 2022',
#  'Markets rally for 4th day; Sensex reclaims 58,000-mark',
#  'Investors richer by over Rs 9 trn in three days of market rally',
#  'Markets fall in early trade on weak global trends',
#  'CFM ARC sells JBF Industries assets to Reliance Industries entity',
#  'Day Trading Guide for July 27, 2022',
#  'Ashishkumar Chauhan quits as BSE chief to join rival NSE as MD & CEO',
#  'Reliance Industries joint CFO flags recession as a worry, bats for rollback of windfall tax',
#  'Reliance Industries shares fall 4% after earnings announcement',
#  'Reliance Industries’ Share Price Drops 4% Even As Outlook Seen Bright After Q1 Miss',
#  'Reliance Industries falls 4% on lower than expected June quarter profit',
#  'Stock Market This Week: Q1 Results, Rupee, US Q2 GDP Data, Other Factors to Watch Out For',
#  'Street Signs: Stocks in overbought territory, PVR shares flat, and more',
#  'RIL skids on O2C, sparks investor concerns',
#  'Reliance Industries consolidated net profit rises 46.30% in the June 2022 quarter',
#  'Reliance Industries warns of global recession headwinds after profit miss',
#  'Reliance Industries reports 46.3% year-on-year rise in consolidated net profit for quarter ended June',
#  'Reliance Industries Q1 Results: Profit Rises 7.9% Sequentially, Misses Estimates',
#  "Reliance Q1 Net Profit At ₹17,955 Crore, Here's A Review Of Their Numbers | Earnings Central",
#  'RIL Q1 Results | Consolidated PAT Rises 46.3% YoY To Rs 17,955 Crore Driven By Refining, Retail Segments',
#  'Reliance Industries shares trading flat ahead of Q1 earnings, here’s what to expect',
#  'Reliance Retail Q1 pre-tax profit up two-fold to Rs 3,897 crore',
#  'RIL Q1FY23 results: A look at the company’s performance in last 4 quarters',
#  'Stocks to Watch: RIL, ITC, CRISIL, PVR, GSFC, RBL Bk, Hindustan Zinc, Sugar',
#  'Reliance Industries posts record consolidated revenues at Rs 2.42 lakh crore in Q1 FY23',
#  'Day Trading Guide for July 21, 2022',
#  'Reliance Industries, ONGC Gain As India Cuts Windfall Taxes On Fuel Exports',
#  'Sensex up 630 pts, Nifty atop 16,500; ONGC, RIL, Infy, TCS top contributors',
#  'How Reliance Industries, ONGC Stand To Gain From Windfall Tax Cut',
#  'Refiners, upstream cos soar on windfall tax cut; CPCL up 11%, Oil India 8%',
#  'Sensex soars 756 points to 55,523, Nifty tops 16,500-mark on windfall tax cut',
#  'Nifty July futures at discount',
#  'Rupee at 80: How top Indian companies hedged themselves for dollar',
#  'Day Trading Guide For July 19, 2022',
#  'Sensex zooms 760 pts, Nifty tops 16,250; IT index up 3%, HDFC Bank dips 1%',
#  'RIL, ONGC Shares Surge As Govt Likely To Consider Lowering Windfall Tax on Petrol, Diesel',
#  'Day Trading Guide for July 14, 2022',
#  'Nifty July futures at discount',
#  'Billionaires Are Vying For Metro’s Indian Wholesale Unit',
#  'Nifty July futures at discount',
#  'Eight of top 10 firms add Rs 1.81 lakh cr in m-cap; HUL, ICICI Bank lead chart',
#  'Future Enterprises offers one-time settlement via sale of assets',
#  'Stocks that will see action on July 7, 2022',
#  'Nifty July futures at discount',
#  'Day trading guide for July 05: Intraday supports, resistances for Nifty50 stocks',
#  'Windfall tax to shave off $12 margin for RIL, severely hit ONGC earnings, say brokerages',
#  'RIL shares in green after Friday’s crash: Check the new target price',
#  'India to withdraw windfall tax if oil prices fall $40 per barrel: Tarun Bajaj',
#  'Windfall tax: $12 margin hit for Reliance; Govt rakes in Rs 1.3 lakh cr | The Financial Express',
#  'Reliance Industries fall more due to windfall tax? windfall tax impact on market;reveal Anil Singhvi',
#  'Shareholders expect Reliance Industries to unlock value in telecom, retail',
#  'Mcap: Three of top 10 firms lose ₹73,630 crore',
#  'Three of Top 10 Firms Lose Rs 73,630 Crore in Market Capitalisation',
#  'Three of top 10 firms lose Rs 73,630 cr in m-cap; RIL biggest drag',
#  'Three of top 10 firms lose Rs 73,630 cr in m-cap; RIL biggest loser',
#  'Reliance Industries Stocks | ONGC Stocks: ITC among Siddhartha Khemka’s top picks for next 12-18 months',
#  'Reliance Industries To See Limited Impact Of Export Duty Hike, Morgan Stanley To JPMorgan Say',
#  'Windfall tax by government to impact oil and gas companies: Analysts',
#  'World’s richest lost $1.4 trillion in 2022 so far: Report. See top 10 list',
#  'Oil India Ltd leads losers in ‘A’ group',
#  'Sensex falls 111 pts, Nifty holds 15,750; RIL sinks 7%, MRPL 10%',
#  'Reliance Industries stock tumbles nearly 9% on ‘export tax’',
#  'Reliance Industries - In Fine Fettle Amid Global Uncertainty: Prabhudas Lilladher',
#  'Reliance Industries, Other Energy Stocks Tumble On Petroleum Export Duty',
#  'SC stays Tripura HC order seeking scrutiny of Mukesh Ambani’s security',
#  'Mukesh Ambani sets succession plan in motion',
#  'SC stays Tripura HC order seeking scrutiny of security cover of Mukesh Ambani & family',
#  'Ambani charts succession plan; hands over telecom business reins to son Akash',
#  'Sensex, Nifty end flat after volatile session; metal, energy stocks shine',
#  'Govt moves SC against Tripura HC order on security cover of Ambani family',
#  'Rajasthan: Congress-led state gets biggest investment pledges from Adani, Ambani, worth Rs 1.68 lakh crore',
#  'Adani, Ambani make Rs 1.68 trn investment pledge in Rajasthan: Report',
#  'Sensex climbs 644 points in early trade amid firm global market trends',
#  'India may see $150 billion investment in hydrogen sector in 10 years, says RIL official | The Financial Express',
#  'Day trading guide for June 23: Intraday supports, resistances for Nifty50 stocks',
#  'Nifty June futures at discount',
#  'India may see $150 bn investment in hydrogen sector in 10 yrs, says RIL official',
#  'Sensex crashes 710 pts to end day at 51,823; Nifty closes session below 15,500',
#  'Market regulatory body fines Reliance over failing to properly disclose 2020 Facebook deal',
#  'Investor pushback sees JP Morgan defend Reliance Industries upgrade',
#  'Day trading guide for June 21: Intraday supports, resistances for Nifty50 stocks',
#  'Market Crash: Top-10 Firms Lose Rs 3.91 Lakh Crore in Market Capitalisation',
#  'Market crash: Top 10 firms lose ₹3.91 lakh crore in market capitalisation; TCS, Reliance Industries biggest laggards',
#  'RIL mulls Revlon acquisition in US after the cosmetics giant filed for bankruptcy: Sources',
#  'IPL media rights: Mukesh Ambani opted out of TV rights chase in battle for cricket deal',
#  "JPMorgan Bets Big On Reliance, Upgrades Stock To 'Overweight' | Market Sell-Off | CNBC-TV18",
#  'Markets go into tailspin after Fed rate hike; Sensex tumbles 1,046 points',
#  'Sensex plummets 1,045.60 points to end at 51,495.79; Nifty tumbles 331.55 points',
#  'Reliance Industries Ltd down for fifth straight session',
#  'Reliance Industries, Oil India See Upgrades From JPMorgan, Morgan Stanley On Refining Upcycle',
#  'Adani Group fastest in valuation growth at 88%, Ambani-led RIL up 13.4% : Report',
#  'Mukesh Ambani’s consumer empire gets a cricket spin',
#  'Top Headlines: IPL media rights & Viacom18, CBDT on cross-border disputes',
#  'Reliance Industries imports over fifth of its oil from Russia: Sources',
#  'IPL media rights auction spills over to third day: Official',
#  'Govt loses appeal to $111 mn arbitration award in dispute with RIL, Shell',
#  'Investors lose over ₹5.16 lakh cr on D-Street in last 5 sessions. Details here',
#  'Top 10 most valued firms lose over Rs 2.29 lakh crore in m-cap',
#  'Top-10 most valued firms lose over Rs 2.29 trn in m-cap; LIC worst hit',
#  'M-cap: Top-10 most valued firms lose over ₹2.29 lakh crore',
#  'India Loses Challenge To $111 Million Arbitration Award In Dispute With Reliance, Shell',
#  'Govt loses challenge to $111 mn arbitration award in dispute with RIL and Shell',
#  'Stocks, rupee tumble as US inflation concerns hit markets',
#  'Bears tighten grip: Sensex crashes 1,000 pts on mounting inflation worries',
#  'Sensex tanks 1,000 points amid weak global cues; banking, IT shares top losers',
#  'Sensex nosedives 1,000 pts; Nifty slumps below 16,300',
#  'Sensex tanks 1,017 pts; Nifty holds 16,200; Bajaj Finance sinks 4%, RIL 3%',
#  'Apollo, Reliance Industries consortium said to make binding bid for Boots',
#  'Stocks to Watch: Wipro, Vedanta, PNB, YES Bank, Tata Power',
#  'Day trading guide for June 08: Intraday supports, resistances for Nifty50 stocks',
#  'Day trading guide for June 07: Intraday supports, resistances for Nifty50 stocks',
#  'Four of the top ten firms add m-cap by ₹2.31 lakh cr; Reliance leading the way',
#  'Why Reliance Industries stock is top gainer for the second straight session today',
#  'Nifty June futures at premium; VIX falls 1.69%',
#  'Stock Markets Succumb to Fag-end Sell-off; Sensex Drops 49 Points',
#  'Mukesh Ambani surpasses Gautam Adani, becomes Asia’s richest man again',
#  'Stocks to Watch: UltraTech, YES Bank, Aether Industries, HDFC']
